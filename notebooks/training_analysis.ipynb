# %%
from IPython.display import Image
Image('/home/islam_tb/Documents/AlgerPlate/training/runs/detect/yolov8s-ep50/results.png')

# %% [markdown]
# ## Week 2 training results
# | Metric | Val set | Test set |
# |--------|---------|----------|
# | mAP@50 | 0.994    | 0.993    |
# | Precision | 0.973 | 0.984    |
# | Recall | 1.000    | 0.975     |

# %% [markdown]
# Validation loss appears to have plateaued toward the later epochs, with only marginal improvements after the mid-training phase. The validation and test mAP@50 are almost identical (0.994 vs 0.993), so there is no meaningful generalization gap.
